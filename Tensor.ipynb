# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabhgupta1qz/100days-ML/blob/main/Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.array(5)
print(a)
a.ndim
# Out:
# 5
# 0

# %%
arr = np.array([1,2,34,5,5])
print(arr)
arr.ndim
# Out:
# [ 1  2 34  5  5]
# 1

# %%
arr = np.array([[1,23,3],[23,45,56],[23,4,5]])
print(arr)
arr.ndim
# Out:
# [[ 1 23  3]
#  [23 45 56]
#  [23  4  5]]
# 2

# %%
tensor3 = np.array([[[1,2,3],[3,4,5]],[[1,2,5],[6,7,8]]])
tensor3.ndim
# Out:
# 3
